# %%
equations & initial conditions

initcondmapk = {mos[0] == mostot, mose1[0] == 0, mosstar[0] == 0, 
   mosstare2[0] == 0, mapk[0] == mapktot, mapkmekstarstar[0] == 0, 
   mapkstar[0] == 0, mapkstarmekstarstar[0] == 0, mapkstarstar[0] == 0, 
   mapkstarmapkpase[0] == 0, mapkstarstarmapkpase[0] == 0, mek[0] == mektot, 
   mekmosstar[0] == 0, mekstar[0] == 0, mekstarmekpase[0] == 0, 
   mekstarmosstar[0] == 0, mekstarstar[0] == 0, mekstarstarmekpase[0] == 0};

initcondswitch = {rasgdp[0] == WT, WE1[0] == 0, WsE2[0] == 0};

eqsswitch = {rasgdp'[t] == -a11 rasgdp[t]*(sostot - WE1[t]) + d11 WE1[t] + 
     k12 WsE2[t], 
   WE1'[t] == a11 rasgdp[t] (sostot - WE1[t]) - (d11 + k11) WE1[t], 
   WsE2'[t] == 
    a12 (WT - rasgdp[t] - WE1[t] - WsE2[t]) (rasgap - WsE2[t]) - (d12 + k12) 
      WsE2[t]};

eqsmapk = {mos'[
     t] == -a1*(mostot - mosstar[t] - mose1[t] - mosstare2[t] - 
        mekmosstar[t] - 
        mekstarmosstar[t])*((WT - rasgdp[t] - WE1[t] - WsE2[t]) - mose1[t]) + 
     d1*mose1[t] + k2*mosstare2[t], 
   mose1'[t] == 
    a1*(mostot - mosstar[t] - mose1[t] - mosstare2[t] - mekmosstar[t] - 
        mekstarmosstar[t])*((WT - rasgdp[t] - WE1[t] - WsE2[t]) - 
        mose1[t]) - (d1 + k1) mose1[t], 
   mosstar'[t] == -a2*mosstar[t]*(e2tot - mosstare2[t]) + d2*mosstare2[t] + 
     k1*mose1[t] + (k3 + d3)*mekmosstar[t] - 
     a3*mosstar[
       t]*(mektot - mekstar[t] - mekstarstar[t] - mekstarmekpase[t] - 
        mekstarstarmekpase[t] - mekmosstar[t] - mekstarmosstar[t] - 
        mapkmekstarstar[t] - mapkstarmekstarstar[t]) + (k5 + d5)*
      mekstarmosstar[t] - a5*mekstar[t]*mosstar[t],
   mosstare2'[t] == 
    a2*mosstar[t] (e2tot - mosstare2[t]) - (d2 + k2)*mosstare2[t], 
   mek'[t] == -a3*(mektot - mekstar[t] - mekstarstar[t] - mekstarmekpase[t] - 
        mekstarstarmekpase[t] - mekmosstar[t] - mekstarmosstar[t] - 
        mapkmekstarstar[t] - mapkstarmekstarstar[t])*mosstar[t] + 
     d3*mekmosstar[t] + k4*mekstarmekpase[t], 
   mekmosstar'[t] == 
    a3*(mektot - mekstar[t] - mekstarstar[t] - mekstarmekpase[t] - 
        mekstarstarmekpase[t] - mekmosstar[t] - mekstarmosstar[t] - 
        mapkmekstarstar[t] - mapkstarmekstarstar[t])*mosstar[t] - (d3 + k3)*
      mekmosstar[t], 
   mekstar'[t] == -a4*
      mekstar[t]*(mekpasetot - mekstarmekpase[t] - mekstarstarmekpase[t]) + 
     d4*mekstarmekpase[t] + k3*mekmosstar[t] + k6*mekstarstarmekpase[t] + 
     d5*mekstarmosstar[t] - a5*mekstar[t]*mosstar[t], 
   mekstarmekpase'[t] == 
    a4*mekstar[
       t]*(mekpasetot - mekstarmekpase[t] - mekstarstarmekpase[t]) - (d4 + 
        k4)*mekstarmekpase[t], 
   mekstarmosstar'[t] == 
    a5*mekstar[t]*mosstar[t] - (d5 + k5)*mekstarmosstar[t], 
   mekstarstar'[t] == 
    k5*mekstarmosstar[t] - 
     a6*mekstarstar[
       t]*(mekpasetot - mekstarmekpase[t] - mekstarstarmekpase[t]) + 
     d6*mekstarstarmekpase[t] - 
     a7*mekstarstar[
       t]*(mapktot - mapkstar[t] - mapkstarstar[t] - mapkstarmapkpase[t] - 
        mapkstarstarmapkpase[t] - mapkmekstarstar[t] - 
        mapkstarmekstarstar[t]) + (d7 + k7)*mapkmekstarstar[t] + (d9 + k9)*
      mapkstarmekstarstar[t] - a9*mapkstar[t]*mekstarstar[t], 
   mekstarstarmekpase'[t] == 
    a6*mekstarstar[
       t]*(mekpasetot - mekstarmekpase[t] - mekstarstarmekpase[t]) - (d6 + 
        k6)*mekstarstarmekpase[t], 
   mapk'[t] == -a7*(mapktot - mapkstar[t] - mapkstarstar[t] - 
        mapkstarmapkpase[t] - mapkstarstarmapkpase[t] - mapkmekstarstar[t] - 
        mapkstarmekstarstar[t])*mekstarstar[t] + d7*mapkmekstarstar[t] + 
     k8*mapkstarmapkpase[t], 
   mapkmekstarstar'[t] == 
    a7*(mapktot - mapkstar[t] - mapkstarstar[t] - mapkstarmapkpase[t] - 
        mapkstarstarmapkpase[t] - mapkmekstarstar[t] - 
        mapkstarmekstarstar[t])*mekstarstar[t] - (d7 + k7) mapkmekstarstar[t],
    mapkstar'[t] == 
    k7*mapkmekstarstar[t] - 
     a8*mapkstar[
       t]*(mapkpasetot - mapkstarmapkpase[t] - mapkstarstarmapkpase[t]) + 
     d8*mapkstarmapkpase[t] - a9*mapkstar[t]*mekstarstar[t] + 
     d9*mapkstarmekstarstar[t] + k10*mapkstarstarmapkpase[t], 
   mapkstarmekstarstar'[t] == 
    a9*mapkstar[t]*mekstarstar[t] - (d9 + k9)*mapkstarmekstarstar[t], 
   mapkstarstar'[
     t] == -a10*
      mapkstarstar[
       t]*(mapkpasetot - mapkstarmapkpase[t] - mapkstarstarmapkpase[t]) + 
     d10*mapkstarstarmapkpase[t] + k9*mapkstarmekstarstar[t], 
   mapkstarmapkpase'[t] == 
    a8*mapkstar[
       t]*(mapkpasetot - mapkstarmapkpase[t] - 
        mapkstarstarmapkpase[t]) - (d8 + k8)*mapkstarmapkpase[t], 
   mapkstarstarmapkpase'[t] == 
    a10*mapkstarstar[
       t]*(mapkpasetot - mapkstarmapkpase[t] - 
        mapkstarstarmapkpase[t]) - (d10 + k10)*mapkstarstarmapkpase[t]};

eqstot = Join[eqsswitch, eqsmapk, initcondswitch, initcondmapk];

eqs = {mos'[
     t] == -a1*(mostot - mosstar[t] - mose1[t] - mosstare2[t] - 
        mekmosstar[t] - mekstarmosstar[t])*(e1tot - mose1[t]) + d1*mose1[t] + 
     k2*mosstare2[t], 
   mose1'[t] == 
    a1*(mostot - mosstar[t] - mose1[t] - mosstare2[t] - mekmosstar[t] - 
        mekstarmosstar[t])*(e1tot - mose1[t]) - (d1 + k1) mose1[t], 
   mosstar'[t] == -a2*mosstar[t]*(e2tot - mosstare2[t]) + d2*mosstare2[t] + 
     k1*mose1[t] + (k3 + d3)*mekmosstar[t] - 
     a3*mosstar[
       t]*(mektot - mekstar[t] - mekstarstar[t] - mekstarmekpase[t] - 
        mekstarstarmekpase[t] - mekmosstar[t] - mekstarmosstar[t] - 
        mapkmekstarstar[t] - mapkstarmekstarstar[t]) + (k5 + d5)*
      mekstarmosstar[t] - a5*mekstar[t]*mosstar[t], 
   mosstare2'[t] == 
    a2*mosstar[t] (e2tot - mosstare2[t]) - (d2 + k2)*mosstare2[t], 
   mos[0] == mostot, mose1[0] == 0, mosstar[0] == 0, mosstare2[0] == 0, 
   mek'[t] == -a3*(mektot - mekstar[t] - mekstarstar[t] - mekstarmekpase[t] - 
        mekstarstarmekpase[t] - mekmosstar[t] - mekstarmosstar[t] - 
        mapkmekstarstar[t] - mapkstarmekstarstar[t])*mosstar[t] + 
     d3*mekmosstar[t] + k4*mekstarmekpase[t], 
   mekmosstar'[t] == 
    a3*(mektot - mekstar[t] - mekstarstar[t] - mekstarmekpase[t] - 
        mekstarstarmekpase[t] - mekmosstar[t] - mekstarmosstar[t] - 
        mapkmekstarstar[t] - mapkstarmekstarstar[t])*mosstar[t] - (d3 + k3)*
      mekmosstar[t], 
   mekstar'[t] == -a4*
      mekstar[t]*(mekpasetot - mekstarmekpase[t] - mekstarstarmekpase[t]) + 
     d4*mekstarmekpase[t] + k3*mekmosstar[t] + k6*mekstarstarmekpase[t] + 
     d5*mekstarmosstar[t] - a5*mekstar[t]*mosstar[t], 
   mekstarmekpase'[t] == 
    a4*mekstar[
       t]*(mekpasetot - mekstarmekpase[t] - mekstarstarmekpase[t]) - (d4 + 
        k4)*mekstarmekpase[t], 
   mekstarmosstar'[t] == 
    a5*mekstar[t]*mosstar[t] - (d5 + k5)*mekstarmosstar[t], 
   mekstarstar'[t] == 
    k5*mekstarmosstar[t] - 
     a6*mekstarstar[
       t]*(mekpasetot - mekstarmekpase[t] - mekstarstarmekpase[t]) + 
     d6*mekstarstarmekpase[t] - 
     a7*mekstarstar[
       t]*(mapktot - mapkstar[t] - mapkstarstar[t] - mapkstarmapkpase[t] - 
        mapkstarstarmapkpase[t] - mapkmekstarstar[t] - 
        mapkstarmekstarstar[t]) + (d7 + k7)*mapkmekstarstar[t] + (d9 + k9)*
      mapkstarmekstarstar[t] - a9*mapkstar[t]*mekstarstar[t], 
   mekstarstarmekpase'[t] == 
    a6*mekstarstar[
       t]*(mekpasetot - mekstarmekpase[t] - mekstarstarmekpase[t]) - (d6 + 
        k6)*mekstarstarmekpase[t], mek[0] == mektot, mekmosstar[0] == 0, 
   mekstar[0] == 0, mekstarmekpase[0] == 0, mekstarmosstar[0] == 0, 
   mekstarstar[0] == 0, mekstarstarmekpase[0] == 0, 
   mapk'[t] == -a7*(mapktot - mapkstar[t] - mapkstarstar[t] - 
        mapkstarmapkpase[t] - mapkstarstarmapkpase[t] - mapkmekstarstar[t] - 
        mapkstarmekstarstar[t])*mekstarstar[t] + d7*mapkmekstarstar[t] + 
     k8*mapkstarmapkpase[t], 
   mapkmekstarstar'[t] == 
    a7*(mapktot - mapkstar[t] - mapkstarstar[t] - mapkstarmapkpase[t] - 
        mapkstarstarmapkpase[t] - mapkmekstarstar[t] - 
        mapkstarmekstarstar[t])*mekstarstar[t] - (d7 + k7) mapkmekstarstar[t],
    mapkstar'[t] == 
    k7*mapkmekstarstar[t] - 
     a8*mapkstar[
       t]*(mapkpasetot - mapkstarmapkpase[t] - mapkstarstarmapkpase[t]) + 
     d8*mapkstarmapkpase[t] - a9*mapkstar[t]*mekstarstar[t] + 
     d9*mapkstarmekstarstar[t] + k10*mapkstarstarmapkpase[t], 
   mapkstarmekstarstar'[t] == 
    a9*mapkstar[t]*mekstarstar[t] - (d9 + k9)*mapkstarmekstarstar[t], 
   mapkstarstar'[
     t] == -a10*
      mapkstarstar[
       t]*(mapkpasetot - mapkstarmapkpase[t] - mapkstarstarmapkpase[t]) + 
     d10*mapkstarstarmapkpase[t] + k9*mapkstarmekstarstar[t], 
   mapkstarmapkpase'[t] == 
    a8*mapkstar[
       t]*(mapkpasetot - mapkstarmapkpase[t] - 
        mapkstarstarmapkpase[t]) - (d8 + k8)*mapkstarmapkpase[t], 
   mapkstarstarmapkpase'[t] == 
    a10*mapkstarstar[
       t]*(mapkpasetot - mapkstarmapkpase[t] - 
        mapkstarstarmapkpase[t]) - (d10 + k10)*mapkstarstarmapkpase[t], 
   mapk[0] == mapktot, mapkmekstarstar[0] == 0, mapkstar[0] == 0, 
   mapkstarmekstarstar[0] == 0, mapkstarstar[0] == 0, 
   mapkstarmapkpase[0] == 0, mapkstarstarmapkpase[0] == 0};


eqsswitchSS = {0 == -a11 rasgdp (sostot - WE1) + d11 WE1 + k12 WsE2, 
  0 == a11 rasgdp (sostot - WE1) - (d11 + k11) WE1, 
  0 == a12 (rasgap - WsE2) (WT - rasgdp - WE1 - WsE2) - (d12 + k12) WsE2}

{0 == -a11 rasgdp (sostot - WE1) + d11 WE1 + k12 WsE2, 
 0 == a11 rasgdp (sostot - WE1) - (d11 + k11) WE1, 
 0 == -(d12 + k12) WsE2 + a12 (rasgap - WsE2) (-rasgdp - WE1 - WsE2 + WT)}

eqscascadeSS = {0 == -a1*(mostot - mosstar - mose1 - mosstare2 - mekmosstar - 
        mekstarmosstar)*(e1tot - mose1) + d1*mose1 + k2*mosstare2, 
   O == a1*(mostot - mosstar - mose1 - mosstare2 - mekmosstar - 
        mekstarmosstar)*(e1tot - mose1) - (d1 + k1) mose1, 
   0 == -a2*mosstar*(e2tot - mosstare2) + d2*mosstare2 + 
     k1*mose1 + (k3 + d3)*mekmosstar - 
     a3*mosstar*(mektot - mekstar - mekstarstar - mekstarmekpase - 
        mekstarstarmekpase - mekmosstar - mekstarmosstar - mapkmekstarstar - 
        mapkstarmekstarstar) + (k5 + d5)*mekstarmosstar - a5*mekstar*mosstar, 
   0 == a2*mosstar (e2tot - mosstare2) - (d2 + k2)*mosstare2, 
   0 == -a3*(mektot - mekstar - mekstarstar - mekstarmekpase - 
        mekstarstarmekpase - mekmosstar - mekstarmosstar - mapkmekstarstar - 
        mapkstarmekstarstar)*mosstar + d3*mekmosstar + k4*mekstarmekpase, 
   0 == a3*(mektot - mekstar - mekstarstar - mekstarmekpase - 
        mekstarstarmekpase - mekmosstar - mekstarmosstar - mapkmekstarstar - 
        mapkstarmekstarstar)*mosstar - (d3 + k3)*mekmosstar, 
   0 == -a4*mekstar*(mekpasetot - mekstarmekpase - mekstarstarmekpase) + 
     d4*mekstarmekpase + k3*mekmosstar + k6*mekstarstarmekpase + 
     d5*mekstarmosstar - a5*mekstar*mosstar, 
   0 == a4*mekstar*(mekpasetot - mekstarmekpase - mekstarstarmekpase) - (d4 + 
        k4)*mekstarmekpase, 
   0 == a5*mekstar*mosstar - (d5 + k5)*mekstarmosstar, 
   0 == k5*mekstarmosstar - 
     a6*mekstarstar*(mekpasetot - mekstarmekpase - mekstarstarmekpase) + 
     d6*mekstarstarmekpase - 
     a7*mekstarstar*(mapktot - mapkstar - mapkstarstar - mapkstarmapkpase - 
        mapkstarstarmapkpase - mapkmekstarstar - mapkstarmekstarstar) + (d7 + 
        k7)*mapkmekstarstar + (d9 + k9)*mapkstarmekstarstar - 
     a9*mapkstar*mekstarstar, 
   0 == a6*mekstarstar*(mekpasetot - mekstarmekpase - 
        mekstarstarmekpase) - (d6 + k6)*mekstarstarmekpase, 
   0 == -a7*(mapktot - mapkstar - mapkstarstar - mapkstarmapkpase - 
        mapkstarstarmapkpase - mapkmekstarstar - mapkstarmekstarstar)*
      mekstarstar + d7*mapkmekstarstar + k8*mapkstarmapkpase, 
   0 == a7*(mapktot - mapkstar - mapkstarstar - mapkstarmapkpase - 
        mapkstarstarmapkpase - mapkmekstarstar - mapkstarmekstarstar)*
      mekstarstar - (d7 + k7) mapkmekstarstar, 
   0 == k7*mapkmekstarstar - 
     a8*mapkstar*(mapkpasetot - mapkstarmapkpase - mapkstarstarmapkpase) + 
     d8*mapkstarmapkpase - a9*mapkstar*mekstarstar + d9*mapkstarmekstarstar + 
     k10*mapkstarstarmapkpase, 
   0 == a9*mapkstar*mekstarstar - (d9 + k9)*mapkstarmekstarstar, 
   0 == -a10*
      mapkstarstar*(mapkpasetot - mapkstarmapkpase - mapkstarstarmapkpase) + 
     d10*mapkstarstarmapkpase + k9*mapkstarmekstarstar, 
   0 == a8*mapkstar*(mapkpasetot - mapkstarmapkpase - 
        mapkstarstarmapkpase) - (d8 + k8)*mapkstarmapkpase, 
   0 == a10*mapkstarstar*(mapkpasetot - mapkstarmapkpase - 
        mapkstarstarmapkpase) - (d10 + k10)*mapkstarstarmapkpase};

Join[eqsswitchSS, eqscascadeSS]

{0 == -a11 rasgdp (sostot - WE1) + d11 WE1 + k12 WsE2, 
 0 == a11 rasgdp (sostot - WE1) - (d11 + k11) WE1, 
 0 == -(d12 + k12) WsE2 + a12 (rasgap - WsE2) (-rasgdp - WE1 - WsE2 + WT), 
 0 == d1 mose1 + k2 mosstare2 - 
   a1 (e1tot - mose1) (-mekmosstar - mekstarmosstar - mose1 - mosstar - 
      mosstare2 + mostot), 
 O == -(d1 + k1) mose1 + 
   a1 (e1tot - mose1) (-mekmosstar - mekstarmosstar - mose1 - mosstar - 
      mosstare2 + mostot), 
 0 == (d3 + k3) mekmosstar + (d5 + k5) mekstarmosstar + k1 mose1 - 
   a5 mekstar mosstar - 
   a3 (-mapkmekstarstar - mapkstarmekstarstar - mekmosstar - mekstar - 
      mekstarmekpase - mekstarmosstar - mekstarstar - mekstarstarmekpase + 
      mektot) mosstar - a2 mosstar (e2tot - mosstare2) + d2 mosstare2, 
 0 == a2 mosstar (e2tot - mosstare2) - (d2 + k2) mosstare2, 
 0 == d3 mekmosstar + k4 mekstarmekpase - 
   a3 (-mapkmekstarstar - mapkstarmekstarstar - mekmosstar - mekstar - 
      mekstarmekpase - mekstarmosstar - mekstarstar - mekstarstarmekpase + 
      mektot) mosstar, 
 0 == -(d3 + k3) mekmosstar + 
   a3 (-mapkmekstarstar - mapkstarmekstarstar - mekmosstar - mekstar - 
      mekstarmekpase - mekstarmosstar - mekstarstar - mekstarstarmekpase + 
      mektot) mosstar, 
 0 == k3 mekmosstar + d4 mekstarmekpase + d5 mekstarmosstar - 
   a4 mekstar (mekpasetot - mekstarmekpase - mekstarstarmekpase) + 
   k6 mekstarstarmekpase - a5 mekstar mosstar, 
 0 == -(d4 + k4) mekstarmekpase + 
   a4 mekstar (mekpasetot - mekstarmekpase - mekstarstarmekpase), 
 0 == -(d5 + k5) mekstarmosstar + a5 mekstar mosstar, 
 0 == (d7 + k7) mapkmekstarstar + (d9 + k9) mapkstarmekstarstar + 
   k5 mekstarmosstar - a9 mapkstar mekstarstar - 
   a7 (-mapkmekstarstar - mapkstar - mapkstarmapkpase - mapkstarmekstarstar - 
      mapkstarstar - mapkstarstarmapkpase + mapktot) mekstarstar - 
   a6 mekstarstar (mekpasetot - mekstarmekpase - mekstarstarmekpase) + 
   d6 mekstarstarmekpase, 
 0 == a6 mekstarstar (mekpasetot - mekstarmekpase - 
      mekstarstarmekpase) - (d6 + k6) mekstarstarmekpase, 
 0 == d7 mapkmekstarstar + k8 mapkstarmapkpase - 
   a7 (-mapkmekstarstar - mapkstar - mapkstarmapkpase - mapkstarmekstarstar - 
      mapkstarstar - mapkstarstarmapkpase + mapktot) mekstarstar, 
 0 == -(d7 + k7) mapkmekstarstar + 
   a7 (-mapkmekstarstar - mapkstar - mapkstarmapkpase - mapkstarmekstarstar - 
      mapkstarstar - mapkstarstarmapkpase + mapktot) mekstarstar, 
 0 == k7 mapkmekstarstar + d8 mapkstarmapkpase + d9 mapkstarmekstarstar - 
   a8 mapkstar (mapkpasetot - mapkstarmapkpase - mapkstarstarmapkpase) + 
   k10 mapkstarstarmapkpase - a9 mapkstar mekstarstar, 
 0 == -(d9 + k9) mapkstarmekstarstar + a9 mapkstar mekstarstar, 
 0 == k9 mapkstarmekstarstar - 
   a10 mapkstarstar (mapkpasetot - mapkstarmapkpase - mapkstarstarmapkpase) + 
   d10 mapkstarstarmapkpase, 
 0 == -(d8 + k8) mapkstarmapkpase + 
   a8 mapkstar (mapkpasetot - mapkstarmapkpase - mapkstarstarmapkpase), 
 0 == a10 mapkstarstar (mapkpasetot - mapkstarmapkpase - 
      mapkstarstarmapkpase) - (d10 + k10) mapkstarstarmapkpase}
